# %% [markdown]
# ## Лабораторна робота №3.
# ***Data Pre-Processing***

# %% [markdown]
# Оцінювання даної роботи буде ураховувати якість ваших візуалізацій (вони можуть незначно відрізнятися від прикладів, але повинні змістовно відображати суть задачі) та опис отриманих вами результатів. При наявності ЛИШЕ візуалізацій без роз'яснень, робота оцінюватися НЕ БУДЕ.
#
# Під час виконання вам дозволено користуватися будь-якими зручними для вас бібліотеками для візуалізації.
#
# Роботи ідентифіковані як ІДЕНТИЧНІ одразу отримують 0 балів.

# %% [markdown]
# Для виконання цієї лабораторної роботи Вам необхідно скористатися вибіркою [titanic.csv](https://gist.github.com/michhar/2dfd2de0d4f8727f873422c5d959fff5).
# Цей датасет ви вже використовували в лабораторній роботі №1 ;)
#
#   ```NB:побудовані графіки та гістограми мають бути змістовними і візуально зрозумілими.```

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
sns.set_context('talk')

# %% [markdown]
# ***Завдання 1.*** Перед початком роботи з будь яким датасетом, необхідно:
# - завантажити датасет;
# - вивести основну статистичну інформацію по числовим змінним;
# - вивести розмірність датасету;
# - перевірити типи змінних і кількість данних по кожній змінній.

# %%
df = pd.read_csv('titanic.csv')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ***Завдання 2.*** Визначити кількість пропущених значень по кожному атрибуту

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Ваші висновки:

# %% [markdown]
# 177 записів мають пропущені значення віку, 687 – відсутню інформацію про каюту, а 2 записи не містять даних про порт посадки.

# %% [markdown]
# ***Завдання 3:*** Побудувати матрицю кореляції

# %% [markdown]
# 1.   Вирахувати кореляційні коефіціенти для набору данних за методом Пірсона
# 2.   Відобразити отриману матрицю коефіціентів у вигляді теплокарти
#
# 3. Описати отримані результати, спираючись на значення коефіціентів кореляції

# %%
num_df= df.select_dtypes(include=['number'])
correlation_matrix = num_df.corr(method='pearson')

plt.figure(figsize=(15, 6))
sns.heatmap(correlation_matrix, vmax=0.6, square=True, annot=True)

plt.show()

# %% [markdown]
# Ваші висновки:

# %% [markdown]
# Можна стверджувати, що рівень виживання найбільше залежав від статі, класу та вартості квитка.

# %% [markdown]
# **Завдання 4:** Як ви могли помітити, у нашому датесеті досить багато пропущених значень, зокрема у атрибута віку пасажирів. Робота з такими даними впливае як на результат моделювання так і на загалом уявлення цілісної картини про дані. Тож для того, що позбавитися пропусків ми використаємо заповнення пропущених значень медіаною за групами.
#
#
#
# 1.   Напишіть функцію, що на вхід приймає датафрейм, назву колонки з пропущеними значеннями та список групуючих колонок та повертає датафрейм з заповненими пропущеними значеннями
# 2.   Наведіть приклад роботи функції та зробіть перевірку на пропущені значення (дивись **завдання 2**)

# %%
def DfClean(ds, attribute, listWithSomeAttributes):
    listWithSomeAttributes.append(attribute)

    for x in listWithSomeAttributes:
        if ds[x].dtypes == object:
            ds[x].replace(np.nan, ds[x].value_counts().idxmax(), inplace = True)
            
        if ds[x].dtypes == float or df[x].dtype == int:
            ds[x].replace(np.nan, ds[x].median(), inplace = True)
            
    return ds
DfClean(df, "Cabin", ['Age', "Embarked"])
# Out:
# /var/folders/z7/qghqpgc54zsb827wnrl67j5c0000gn/T/ipykernel_43756/1603982804.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ds[x].replace(np.nan, ds[x].median(), inplace = True)
# /var/folders/z7/qghqpgc54zsb827wnrl67j5c0000gn/T/ipykernel_43756/1603982804.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
#
# ***Завдання 5:*** В моделях машинного навчання інснує велика проблема опрацювання безперервних змінних. Потрібно перетворити безперервні значення в категоріальні.
#
# Максимальний вік пасажира - ```80 років```.
#
# Отже, давайте розділимо діапазон від ```0 до 80``` на ```5``` осередків.
#
# Додайте до нашого датасету нову колонку ```Age_bin```, в якій будуть значення ```0, 1, 2, 3, 4```відповідно кожній віковій групі.
#
# Побудуйте графік, який відображає кількість виживших у кожній віковій категорії.

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)

bins = [0, 16, 32, 48, 64, 80]
labels = [0, 1, 2, 3, 4]        
df['Age_bin'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)
survived = df[df['Survived'] == 1]

plt.figure(figsize=(12, 8))
age_counts = survived['Age_bin'].value_counts().sort_index()
plt.bar(age_counts.index.astype(str), age_counts.values, width=0.5)
plt.title("Survived by Age Category")
plt.show()
# Out:
# /var/folders/z7/qghqpgc54zsb827wnrl67j5c0000gn/T/ipykernel_43756/687503832.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)

# %% [markdown]
# Ваші висновки:

# %% [markdown]
# Розділивши на вікові групи [0, 16, 32, 48, 64, 80] = [0, 1, 2, 3, 4], можна побачити, що найвищий рівень виживання спостерігається у віковій категорії 16-32 роки, тоді як найнижчий – у групі 64-80 років.

# %% [markdown]
# ***Завдання 6:*** Так як змінна ```fare``` також є неперервною її треба закодувати до ```порядкової шкали```
# Для цього скоритайтесь функцією ```pandas.qcut```.
# [pandas.qcut](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.qcut.html)
# - необхідно перевірити, чи є вірною гіпотеза про те, що кількість виживших пасажирів для квартильних значеннь змінної ```fare``` відрізняється, та чи доцільно використовувати кодування на цю змінну(для подальшої роботи з закодованою фичею)

# %%
df['Fare_bin'] = pd.qcut(df['Fare'], 4, labels=[0, 1, 2, 3])
survival_by_fare_bin = df.groupby(['Fare_bin', 'Survived']).size().unstack(fill_value=0)
print(survival_by_fare_bin)
# Out:
# Survived    0    1
# Fare_bin
# 0         179   44
# 1         156   68
# 2         121  101
# 3          93  129
# /var/folders/z7/qghqpgc54zsb827wnrl67j5c0000gn/T/ipykernel_43756/540780194.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_by_fare_bin = df.groupby(['Fare_bin', 'Survived']).size().unstack(fill_value=0)

# %% [markdown]
# Ваші висновки:

# %% [markdown]
#  Гіпотеза про зв’язок між вартістю квитка та шансами на виживання підтвердилася. Вищі ціни квитків відповідали більшій кількості пасажирів, які вижили. Кодування ціни за квартилями є доцільним, оскільки воно чітко розділяє пасажирів на групи за рівнем вартості квитка.

# %% [markdown]
# ***Завдання 7:*** Необхідно створити нові змінні ```Family_size``` та ```Alone``` та проаналізувати їх. Змінна ```Family_size``` передає суму змінних ```Parch``` та ```SibSp```. Змінна ```Family_size``` буде відібражати комбіновані дані, які необхідні для перевірки гіпотези, що ```виживання пасажирів залежіть від кількості членів їх сім'ї```. Змінна ```Alone``` позначає наявніть сім'ї.

# %%
df['Family_size'] = df['Parch'] + df['SibSp']
df['Alone'] = df['Family_size'].apply(lambda x: 1 if x == 0 else 0)

print(df[['Family_size', 'Alone']].head())
# Out:
#    Family_size  Alone
# 0            1      0
# 1            1      0
# 2            0      1
# 3            1      0
# 4            0      1

# %% [markdown]
# Більш чисельні родини мали вищі шанси на виживання.

# %% [markdown]
# ***Завдання 8:*** Видалити атрибути які є ***НЕрелевантними*** або містять багато пропущених значень. Аргументувати свій вибір.

# %%
cdf = df.drop(['Ticket', 'Cabin', 'PassengerId','Name','Title'], axis = 1)
cdf.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 cdf = df.drop(['Ticket', 'Cabin', 'PassengerId','Name','Title'], axis = 1)
#       2 cdf.head()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %% [markdown]
# Ваші висновки: Стовпці Ticket, Cabin, PassengerId, Name та Title не мають значного впливу на виживаність. Номер квитка не надає суттєвої корисної інформації. У даних часто зустрічаються пропуски в стовпці Cabin. PassengerId є лише унікальним ідентифікатором. Title не має важливості для моделювання.

# %% [markdown]
# ***Завдання 9:*** Перетворіть змінні ```Sex```, ```Embarked``` та ```Title``` в числові значення

# %%
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})

df['Embarked'] = df['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})

df['Title'] = df['Name'].str.extract('([A-Za-z]+)\.', expand=False)
title_mapping = {title: idx for idx, title in enumerate(df['Title'].unique())}
df['Title'] = df['Title'].map(title_mapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
#       3 df['Embarked'] = df['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})
#       5 df['Title'] = df['Name'].str.extract('([A-Za-z]+)\.', expand=False)
#
# NameError: name 'df' is not defined

# %% [markdown]
# Ваші висновки:

# %% [markdown]
# ***Завдання 10.*** Побудувати графіки всіх категоріальних змінних та проаналізувати скільки кожна категорія містить даних
#
# 1.   виділити категоріальні змінні
# 2.   побудувати сітку графіків кількості спотрережень по кожній категорії

# %%
fig, axes = plt.subplots(3, 3, figsize=(15, 15))  

sns.countplot(x="Survived", data=df, ax=axes[0, 0])
sns.countplot(x="Sex", data=df, ax=axes[0, 1])
sns.countplot(x="Embarked", data=df, ax=axes[0, 2])
sns.countplot(x="SibSp", data=df, ax=axes[1, 0])
sns.countplot(x="Age_bin", data=df, ax=axes[1, 1])
sns.countplot(x="Alone", data=df, ax=axes[1, 2])
sns.countplot(x="Parch", data=df, ax=axes[2, 0])
sns.countplot(x="Fare_bin", data=df, ax=axes[2, 1])
sns.countplot(x="Pclass", data=df, ax=axes[2, 2])

fig.tight_layout() 
plt.show()

# %% [markdown]
# Ваші висновки:

# %% [markdown]
# Більше ніж 500 пасажирів не вижили, а понад 300 — вижили.
#
# Більше ніж 500 чоловіків і понад 300 жінок були серед пасажирів.
#
# Понад 600 пасажирів сідали в порту S, 159 — в порту C, менше ніж 100 — в порту Q.
#
# Більше ніж 600 пасажирів подорожували без братів чи сестер, а 200 — з одним братом чи сестрою.
#
# 500 пасажирів подорожували з родиною, а 350 — самостійно.
#
# 500 пасажирів подорожували в 3-му класі, 200 — в 1-му класі, а понад 150 — в 2-му класі. З цього видно, що 3-й клас був найбільш популярним.

# %% [markdown]
# ***Завдання 11.*** Побудувати діаграми розподілу всіх числових змінних

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10)) 

sns.histplot(data=df, x="Age", ax=axes[0, 0])
sns.histplot(data=df, x="Fare", ax=axes[0, 1])
sns.countplot(x="Parch", data=df, ax=axes[1, 0])
sns.countplot(x="SibSp", data=df, ax=axes[1, 1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 fig, axes = plt.subplots(2, 2, figsize=(12, 10))
#       3 sns.histplot(data=df, x="Age", ax=axes[0, 0])
#       4 sns.histplot(data=df, x="Fare", ax=axes[0, 1])
#
# NameError: name 'plt' is not defined

# %% [markdown]
# Ваші висновки:

# %% [markdown]
# ##Співвіднонешшя між всіма числовими змінними
#
# ***Завдання 12.*** В деяких випадках візуалізація співвідношення між змінними (числовими, категоріальними) дає можливість побачити викиди в змінних та знайти приховані тенденції і виділити навіть додаткові змінні. Тому, необхідно:
# 1) побудувати графіки співвідношення між всіма числовими змінними.
# 2) описати отримані співвідношення і запропонувати як їх можна (чи не можна) використати

# %%
plt.figure(figsize=(13, 8))
sns.heatmap(df.select_dtypes(include=['number']).corr(method='pearson'), annot=True, linewidths=0.3)
plt.show()

# %% [markdown]
# Ваші висновки:

# %% [markdown]
# Між ціною квитка та шансами на виживання спостерігається слабка позитивна кореляція: пасажири, які платили більше за квиток, мали вищі шанси на виживання.
#
# Кореляція між віком (Age) та вартістю квитка (Fare) є слабкою та негативною, тому цей фактор не є корисним для моделювання.
#
# Кореляційний аналіз показує, що виживаність найбільше залежить від статі, класу та вартості квитка.

# %% [markdown]
# Кожне правильно виконане завдання буде оцінюватись в ```2 бали```.
